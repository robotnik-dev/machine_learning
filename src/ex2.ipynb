# %% [markdown]
# ### Aufgabe 2
# Schreibe eine Funktion `show_images(i)`, die eine Zahl `i` nimmt und ein grid von `i`x`i` zufällig gewählten Trainingsbildern anzeigt. Dabei sollen auch die zugehörigen Labels der Bilder angezeigt werden.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from utils import load_image, show_images

# %% [markdown]
# use:
# - `np.random.randint()` um eine zufällige Zahl zu generieren. Damit lässt sich ein zufälliges Bild wählen.
# - `os.listdir()` um den Inhalt eines Ordners zu bekommen.
# - `figure = plt.figure()` um ein Abbildungsobjekt zu erstellen.
# - `figure.add_subplot()` um in einer Abbildung eine "Teilabbildung" zu erstellen.

# %%
p = "../data/MYON/train/"

# %%
show_images(grid_size=8, path_to_images=p)
